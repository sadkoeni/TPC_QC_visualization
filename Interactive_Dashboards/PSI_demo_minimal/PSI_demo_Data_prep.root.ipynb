# %%
from Dataprep import *
DataObj = prepDataObject()
c = DataObj.drawNtupleTPC()
# Out:
# Error in <TBufferFile::CheckByteCount>: object of class TObjArray read too many bytes: 45 instead of 41
# Warning in <TBufferFile::CheckByteCount>: TObjArray::Streamer() not in sync with data on file Train_554.root, fix Streamer()
# Error in <TBufferFile::CheckByteCount>: object of class TList read too many bytes: 1676329083 instead of 602587259
# Warning in <TBufferFile::CheckByteCount>: TList::Streamer() not in sync with data on file Train_554.root, fix Streamer()
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
DataObj.df.head()
# Out:
#           p        pt  TPCSignal  TPCnSigmaHe3  Charge  TOF_beta     DCAxy  \
# 0  3.256687  3.173264   63.18750    -17.341555     1.0  0.750399  0.003115
# 1  4.369119  3.659813   69.62500    -17.776957     1.0  0.875501 -0.003680
# 2  4.162671  3.814589   50.06250    -13.468337     1.0  0.856265  0.000319
# 3  5.616655  4.748786   60.46875    -18.591265     1.0  0.915768 -0.002514
# 4  3.681391  3.635892   57.75000    -17.821180     1.0  0.823364 -0.000212
#
#        DCAz     TOFm2  TPCNClusters  ITSNClusters  TPCClusters4dEdx       Eta  \
# 0  0.007951  8.229053         151.0           5.0             149.0 -0.228801
# 1 -0.003363  5.815103         157.0           4.0             158.0 -0.612950
# 2  0.004409  6.305672         117.0           6.0              77.0 -0.424017
# 3  0.002937  6.070220         151.0           5.0             157.0  0.595728
# 4 -0.014273  6.438637         151.0           4.0             153.0 -0.158036
#
# ...
